# %%
import pandas as pd

# %%
df = pd.read_csv("/content/spotify_millsongdata.csv")

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df =df.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#                artist                  song  \
# 0             Nirvana  Scentless Apprentice
# 1      Ellie Goulding   Love Me Like You Do
# 2                Inna               Tell Me
# 3          Thin Lizzy            The Rocker
# 4  Horrible Histories       William Wallace
# 5     David Allan Coe           Honey Don't
# 6        Mariah Carey               Circles
# 7           Marillion       Fantastic Place
# 8        Judas Priest          Thunder Road
# 9  Marianne Faithfull           I'm The Sky
#
#                                                 text
# 0  Like most babies smell like butter  \r\nHis sm...
# 1  [Verse 1]  \r\nYou're the light, you're the ni...
# 2  [Hook:]  \r\nTell me the truth  \r\nTell me yo...
# 3  I am your main man if you're looking for troub...
# 4  I am William Wallace  \r\nMy life was a myster...
# 5  By David Allan Coe  \r\nI'VE DONE SOME RAMBLIN...
# 6  Ever since you left me  \r\nI've been trying t...
# 7  Islands are mountain-tops  \r\n  \r\nIt's alwa...
# 8  Red light, green light  \r\nI'm coming home to...
# 9  I'm the sky  \r\n'Cause the sky doesn't sing i...

# %%
df['text'][0]
# Out:
# "Like most babies smell like butter  \r\nHis smell smelled like no other  \r\nHe was born scentless and senseless  \r\nHe was born a scentless apprentice  \r\n  \r\nGo away - get away, get away, get a-way  \r\nEvery wet nurse refused to feed him  \r\nElectrolytes smell like semen  \r\n  \r\nI promise not to sell your perfumed secrets  \r\nThere are countless formulas for pressing flowers  \r\n  \r\nI lie in the soll and fertilize mushrooms  \r\nLeaking out gas fumes are made into perfume  \r\n  \r\nYou can't fire me because I quit  \r\nThrow me in the fire and I won't throw a fit\r\n\r\n"

# %%
df.shape
# Out:
# (5000, 3)

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)

# %%
import nltk
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def tokenization(txt):
    tokens = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in tokens]
    return " ".join(stemming)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidvector.fit_transform(df['text'])
similer = cosine_similarity(matrix)

# %%
cosine_similarity(matrix)
# Out:
# array([[1.        , 0.06376826, 0.00437722, ..., 0.00445599, 0.01000249,
#         0.03647806],
#        [0.06376826, 1.        , 0.02603017, ..., 0.02574849, 0.03365174,
#         0.14101759],
#        [0.00437722, 0.02603017, 1.        , ..., 0.10836214, 0.04987135,
#         0.05931551],
#        ...,
#        [0.00445599, 0.02574849, 0.10836214, ..., 1.        , 0.09285258,
#         0.01266843],
#        [0.01000249, 0.03365174, 0.04987135, ..., 0.09285258, 1.        ,
#         0.00607532],
#        [0.03647806, 0.14101759, 0.05931551, ..., 0.01266843, 0.00607532,
#         1.        ]])

# %%
similer[0]
# Out:
# array([1.        , 0.06376826, 0.00437722, ..., 0.00445599, 0.01000249,
#        0.03647806])

# %%
df[df['song'] =='Love Me Like You Do']
# Out:
#               artist                 song  \
# 1     Ellie Goulding  Love Me Like You Do
# 2232   Justin Bieber  Love Me Like You Do
#
#                                                    text
# 1     [verse 1]  \r you're the light, you're the nig...
# 2232  love me like you do  \r love me like you do  \...

# %%
def recommendation(song_df):
    idx = df[df['song'] == song_df].index[0]
    distances = sorted(list(enumerate(similer[idx])),reverse=True,key=lambda x:x[1])

    songs = []
    for m_id in distances[1:11]:
        songs.append(df.iloc[m_id[0]].song)

    return songs

# %%
recommendation('Love Me Like You Do')
# Out:
# ['Touch',
#  'Like I Would',
#  'Touch Me',
#  'Love Me Like You Do',
#  'Love Who You Love',
#  'Hawkmoon 269',
#  "Love O'love",
#  'Did I Ever Tell You',
#  'I Will Always Love You',
#  'I Love The Little Things']

# %%
import pickle
pickle.dump(similer,open('similarity.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))
